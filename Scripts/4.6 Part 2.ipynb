# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Import Data

# %%
path = r"C:\Users\Zachu\Downloads\08-25-2024_Insta_Cart_Basket_Analysis"
orders_products_combined = pd.read_pickle(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_combined.pkl'))
products_checked = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', 'products_checked.csv'))

# %% [markdown]
# # Data Output Checks

# %%
products_checked.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
products_checked.shape
# Out:
# (49672, 6)

# %%
orders_products_combined.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0           0   2539329        1             1          2                  8
# 1           0   2539329        1             1          2                  8
# 2           0   2539329        1             1          2                  8
# 3           0   2539329        1             1          2                  8
# 4           0   2539329        1             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
orders_products_combined.shape
# Out:
# (32434489, 11)

# %% [markdown]
# # Merge ords_prods_combined with products_checked

# %%
# Drop Unnamed columns in df_products_checked
products_checked = products_checked.drop(columns = ['Unnamed: 0'])

# %%
# Drop Unnamed and Merge columns in orders_products_combined
orders_products_combined = orders_products_combined.drop(columns = ['Unnamed: 0', '_merge'])

# %%
ords_prods_merge = orders_products_combined.merge(products_checked, on = 'product_id', indicator = True)
ords_prods_merge
# Out:
#           order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0          2539329        1             1          2                  8
# 1          2539329        1             1          2                  8
# 2          2539329        1             1          2                  8
# 3          2539329        1             1          2                  8
# 4          2539329        1             1          2                  8
# ...            ...      ...           ...        ...                ...
# 32404854   2977660   206209            13          1                 12
# 32404855   2977660   206209            13          1                 12
# 32404856   2977660   206209            13          1                 12
# 32404857   2977660   206209            13          1                 12
# 32404858   2977660   206209            13          1                 12
#
#           days_since_prior_order  product_id  add_to_cart_order  reordered  \
# ...

# %%
ords_prods_merge['prices'].describe()
# Out:
# count    3.240486e+07
# mean     1.198023e+01
# std      4.956554e+02
# min      1.000000e+00
# 25%      4.200000e+00
# 50%      7.400000e+00
# 75%      1.130000e+01
# max      9.999900e+04
# Name: prices, dtype: float64

# %%
ords_prods_merge['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
# Export merged file
ords_prods_merge.to_pickle(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_merged.pkl'))
